# %%
import matplotlib.pyplot as plt
import pandas as pd

data_worries_age_gender = pd.read_csv('../Analysis Data/data_worries_age_gender.csv')
data_worries_age_gender
# Out:
#         Age What is your gender?  \
# 0   18 - 29               Female
# 1   18 - 29               Female
# 2   18 - 29               Female
# 3   18 - 29               Female
# 4   18 - 29               Female
# 5   18 - 29                 Male
# 6   18 - 29                 Male
# 7   18 - 29                 Male
# 8   18 - 29                 Male
# 9   18 - 29                 Male
# 10  30 - 44               Female
# 11  30 - 44               Female
# 12  30 - 44               Female
# 13  30 - 44               Female
# 14  30 - 44               Female
# 15  30 - 44                 Male
# 16  30 - 44                 Male
# 17  30 - 44                 Male
# 18  30 - 44                 Male
# 19  30 - 44                 Male
# 20  45 - 59               Female
# 21  45 - 59               Female
# 22  45 - 59               Female
# 23  45 - 59               Female
# 24  45 - 59               Female
# 25  45 - 59                 Male
# 26  45 - 59                 Male
# ...

# %%
data_experience_age_gender = pd.read_csv('../Analysis Data/data_experience_age_gender.csv')
data_experience_age_gender
# Out:
#         Age What is your gender? Have you ever experienced an earthquake?  \
# 0   18 - 29               Female              Yes, one or more major ones
# 1   18 - 29               Female                                       No
# 2   18 - 29               Female              Yes, one or more minor ones
# 3   18 - 29                 Male              Yes, one or more major ones
# 4   18 - 29                 Male                                       No
# 5   18 - 29                 Male              Yes, one or more minor ones
# 6   30 - 44               Female              Yes, one or more major ones
# 7   30 - 44               Female                                       No
# 8   30 - 44               Female              Yes, one or more minor ones
# 9   30 - 44                 Male              Yes, one or more major ones
# 10  30 - 44                 Male                                       No
# 11  30 - 44                 Male              Yes, one or more minor ones
# ...

# %%
data_bigone_age_gender = pd.read_csv('../Analysis Data/data_bigone_age_gender.csv')
data_bigone_age_gender
# Out:
#         Age What is your gender?  \
# 0   18 - 29               Female
# 1   18 - 29               Female
# 2   18 - 29                 Male
# 3   18 - 29                 Male
# 4   30 - 44               Female
# 5   30 - 44               Female
# 6   30 - 44                 Male
# 7   30 - 44                 Male
# 8   45 - 59               Female
# 9   45 - 59               Female
# 10  45 - 59                 Male
# 11  45 - 59                 Male
# 12       60               Female
# 13       60               Female
# 14       60                 Male
# 15       60                 Male
#
#    Do you think the "Big One" will occur in your lifetime?  Count
# 0                                                 Yes          47
# 1                                                  No          62
# 2                                                 Yes          41
# 3                                                  No          65
# ...

# %%
data_precautions_age_gender = pd.read_csv('../Analysis Data/data_precautions_age_gender.csv')
data_precautions_age_gender
# Out:
#         Age What is your gender?  \
# 0   18 - 29               Female
# 1   18 - 29               Female
# 2   18 - 29                 Male
# 3   18 - 29                 Male
# 4   30 - 44               Female
# 5   30 - 44               Female
# 6   30 - 44                 Male
# 7   30 - 44                 Male
# 8   45 - 59               Female
# 9   45 - 59               Female
# 10  45 - 59                 Male
# 11  45 - 59                 Male
# 12       60               Female
# 13       60               Female
# 14       60                 Male
# 15       60                 Male
#
#    Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?  \
# 0                                                 Yes
# 1                                                  No
# 2                                                 Yes
# 3                                                  No
# ...

# %%
data_sa_age_gender = pd.read_csv('../Analysis Data/data_sa_age_gender.csv')
data_sa_age_gender
# Out:
#         Age What is your gender?  \
# 0   18 - 29               Female
# 1   18 - 29               Female
# 2   18 - 29               Female
# 3   18 - 29               Female
# 4   18 - 29               Female
# 5   18 - 29                 Male
# 6   18 - 29                 Male
# 7   18 - 29                 Male
# 8   18 - 29                 Male
# 9   18 - 29                 Male
# 10  30 - 44               Female
# 11  30 - 44               Female
# 12  30 - 44               Female
# 13  30 - 44               Female
# 14  30 - 44               Female
# 15  30 - 44                 Male
# 16  30 - 44                 Male
# 17  30 - 44                 Male
# 18  30 - 44                 Male
# 19  30 - 44                 Male
# 20  45 - 59               Female
# 21  45 - 59               Female
# 22  45 - 59               Female
# 23  45 - 59               Female
# 24  45 - 59               Female
# 25  45 - 59                 Male
# 26  45 - 59                 Male
# ...

# %%
data_yellowstone_age_gender  = pd.read_csv('../Analysis Data/data_yellowstone_age_gender.csv')
data_yellowstone_age_gender
# Out:
#         Age What is your gender?  \
# 0   18 - 29               Female
# 1   18 - 29               Female
# 2   18 - 29               Female
# 3   18 - 29               Female
# 4   18 - 29               Female
# 5   18 - 29                 Male
# 6   18 - 29                 Male
# 7   18 - 29                 Male
# 8   18 - 29                 Male
# 9   18 - 29                 Male
# 10  30 - 44               Female
# 11  30 - 44               Female
# 12  30 - 44               Female
# 13  30 - 44               Female
# 14  30 - 44               Female
# 15  30 - 44                 Male
# 16  30 - 44                 Male
# 17  30 - 44                 Male
# 18  30 - 44                 Male
# 19  30 - 44                 Male
# 20  45 - 59               Female
# 21  45 - 59               Female
# 22  45 - 59               Female
# 23  45 - 59               Female
# 24  45 - 59               Female
# 25  45 - 59                 Male
# 26  45 - 59                 Male
# ...

# %%
data_worries_region = pd.read_csv('../Analysis Data/data_worries_region.csv')
data_worries_region
# Out:
#              US Region In general, how worried are you about earthquakes?  \
# 0   East North Central                                       Very worried
# 1   East North Central                                  Extremely worried
# 2   East North Central                                   Somewhat worried
# 3   East North Central                                     Not so worried
# 4   East North Central                                 Not at all worried
# 5   East South Central                                  Extremely worried
# 6   East South Central                                   Somewhat worried
# 7   East South Central                                     Not so worried
# 8   East South Central                                 Not at all worried
# 9      Middle Atlantic                                       Very worried
# 10     Middle Atlantic                                  Extremely worried
# 11     Middle Atlantic                                   Somewhat worried
# ...

# %%
data_earthquake_region = pd.read_csv('../Analysis Data/data_earthquake_region.csv')
data_earthquake_region
# Out:
#              US Region Have you ever experienced an earthquake?  Count
# 0   East North Central              Yes, one or more major ones      3
# 1   East North Central                                       No     61
# 2   East North Central              Yes, one or more minor ones     76
# 3   East South Central                                       No     20
# 4   East South Central              Yes, one or more minor ones     20
# 5      Middle Atlantic              Yes, one or more major ones      8
# 6      Middle Atlantic                                       No     48
# 7      Middle Atlantic              Yes, one or more minor ones     81
# 8             Mountain                                       No     16
# 9             Mountain              Yes, one or more major ones     22
# 10            Mountain              Yes, one or more minor ones     29
# 11         New England              Yes, one or more major ones      3
# ...

# %%
data_sf_region = pd.read_csv('../Analysis Data/data_sf_region.csv')
data_sf_region
# Out:
#              US Region How familiar are you with the San Andreas Fault line?  \
# 0   East North Central                                 Extremely familiar
# 1   East North Central                                Not at all familiar
# 2   East North Central                                    Not so familiar
# 3   East North Central                                      Very familiar
# 4   East North Central                                  Somewhat familiar
# 5   East South Central                                    Not so familiar
# 6   East South Central                                 Extremely familiar
# 7   East South Central                                Not at all familiar
# 8   East South Central                                      Very familiar
# 9   East South Central                                  Somewhat familiar
# 10     Middle Atlantic                                 Extremely familiar
# 11     Middle Atlantic                                Not at all familiar
# ...

# %%
data_yellowstone_region = pd.read_csv('../Analysis Data/data_yellowstone_region.csv')
data_yellowstone_region
# Out:
#              US Region  \
# 0   East North Central
# 1   East North Central
# 2   East North Central
# 3   East North Central
# 4   East North Central
# 5   East South Central
# 6   East South Central
# 7   East South Central
# 8   East South Central
# 9   East South Central
# 10     Middle Atlantic
# 11     Middle Atlantic
# 12     Middle Atlantic
# 13     Middle Atlantic
# 14     Middle Atlantic
# 15            Mountain
# 16            Mountain
# 17            Mountain
# 18            Mountain
# 19            Mountain
# 20         New England
# 21         New England
# 22         New England
# 23         New England
# 24         New England
# 25             Pacific
# 26             Pacific
# 27             Pacific
# 28             Pacific
# 29             Pacific
# 30      South Atlantic
# 31      South Atlantic
# 32      South Atlantic
# 33      South Atlantic
# 34      South Atlantic
# 35  West North Central
# 36  West North Central
# 37  West North Central
# ...

# %%
data_precautions_region = pd.read_csv('../Analysis Data/data_precautions_region.csv')
data_precautions_region
# Out:
#              US Region  \
# 0   East North Central
# 1   East North Central
# 2   East South Central
# 3   East South Central
# 4      Middle Atlantic
# 5      Middle Atlantic
# 6             Mountain
# 7             Mountain
# 8          New England
# 9          New England
# 10             Pacific
# 11             Pacific
# 12      South Atlantic
# 13      South Atlantic
# 14  West North Central
# 15  West North Central
# 16  West South Central
# 17  West South Central
#
#    Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?  \
# 0                                                 Yes
# 1                                                  No
# 2                                                 Yes
# 3                                                  No
# 4                                                 Yes
# 5                                                  No
# ...

# %%
data_precautions_income = pd.read_csv('../Analysis Data/data_precautions_income.csv')
data_precautions_income
# Out:
#    How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                        $0 to $9,999
# 1                                        $0 to $9,999
# 2                                  $10,000 to $24,999
# 3                                  $10,000 to $24,999
# 4                                $100,000 to $124,999
# 5                                $100,000 to $124,999
# 6                                $125,000 to $149,999
# 7                                $125,000 to $149,999
# 8                                $150,000 to $174,999
# 9                                $150,000 to $174,999
# 10                               $175,000 to $199,999
# 11                               $175,000 to $199,999
# 12                                    $200,000 and up
# 13                                    $200,000 and up
# 14                                 $25,000 to $49,999
# 15                                 $25,000 to $49,999
# ...
